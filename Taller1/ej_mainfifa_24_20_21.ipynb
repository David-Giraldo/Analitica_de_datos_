# %% [markdown]
# <a href="https://colab.research.google.com/github/David-Giraldo/Analitica_de_datos_/blob/main/Taller1/ej_mainfifa_24_20_21.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#cargar datos desde drive acceso libre
FILEID = "15QxsIm_jMfHEy6Y--6o19IWgr66oiTRe"
# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id='$FILEID -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id="$FILEID -O codigos.zip && rm -rf /tmp/cookies.txt
# !unzip codigos.zip
# !dir
# Out:
# --2021-03-24 19:10:38--  https://docs.google.com/uc?export=download&confirm=&id=15QxsIm_jMfHEy6Y--6o19IWgr66oiTRe
# Resolving docs.google.com (docs.google.com)... 172.217.214.138, 172.217.214.101, 172.217.214.100, ...
# Connecting to docs.google.com (docs.google.com)|172.217.214.138|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-08-50-docs.googleusercontent.com/docs/securesc/vnk7lo5ef8d0k567ohl833p9anku38ao/gjbmjioqcpvng4pbaa41re70p8avv2es/1616613000000/09173029842254050324/10254986542902807490Z/15QxsIm_jMfHEy6Y--6o19IWgr66oiTRe?e=download [following]
# --2021-03-24 19:10:41--  https://doc-08-50-docs.googleusercontent.com/docs/securesc/vnk7lo5ef8d0k567ohl833p9anku38ao/gjbmjioqcpvng4pbaa41re70p8avv2es/1616613000000/09173029842254050324/10254986542902807490Z/15QxsIm_jMfHEy6Y--6o19IWgr66oiTRe?e=download
# Resolving doc-08-50-docs.googleusercontent.com (doc-08-50-docs.googleusercontent.com)... 142.251.6.132, 2607:f8b0:4001:c5a::84
# Connecting to doc-08-50-docs.googleusercontent.com (doc-08-50-docs.googleusercontent.com)|142.251.6.132|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://docs.google.com/nonceSigner?nonce=pp48m4ead18kg&continue=https://doc-08-50-docs.googleusercontent.com/docs/securesc/vnk7lo5ef8d0k567ohl833p9anku38ao/gjbmjioqcpvng4pbaa41re70p8avv2es/1616613000000/09173029842254050324/10254986542902807490Z/15QxsIm_jMfHEy6Y--6o19IWgr66oiTRe?e%3Ddownload&hash=coj1v8d82fflb3p0nm8rl1stnbjpgrnj [following]
# --2021-03-24 19:10:41--  https://docs.google.com/nonceSigner?nonce=pp48m4ead18kg&continue=https://doc-08-50-docs.googleusercontent.com/docs/securesc/vnk7lo5ef8d0k567ohl833p9anku38ao/gjbmjioqcpvng4pbaa41re70p8avv2es/1616613000000/09173029842254050324/10254986542902807490Z/15QxsIm_jMfHEy6Y--6o19IWgr66oiTRe?e%3Ddownload&hash=coj1v8d82fflb3p0nm8rl1stnbjpgrnj
# Connecting to docs.google.com (docs.google.com)|172.217.214.138|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://doc-08-50-docs.googleusercontent.com/docs/securesc/vnk7lo5ef8d0k567ohl833p9anku38ao/gjbmjioqcpvng4pbaa41re70p8avv2es/1616613000000/09173029842254050324/10254986542902807490Z/15QxsIm_jMfHEy6Y--6o19IWgr66oiTRe?e=download&nonce=pp48m4ead18kg&user=10254986542902807490Z&hash=s0jjraaceikq3ugd80k4si0hsbentq2q [following]
# --2021-03-24 19:10:41--  https://doc-08-50-docs.googleusercontent.com/docs/securesc/vnk7lo5ef8d0k567ohl833p9anku38ao/gjbmjioqcpvng4pbaa41re70p8avv2es/1616613000000/09173029842254050324/10254986542902807490Z/15QxsIm_jMfHEy6Y--6o19IWgr66oiTRe?e=download&nonce=pp48m4ead18kg&user=10254986542902807490Z&hash=s0jjraaceikq3ugd80k4si0hsbentq2q
# Connecting to doc-08-50-docs.googleusercontent.com (doc-08-50-docs.googleusercontent.com)|142.251.6.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘codigos.zip’
#
# codigos.zip             [ <=>                ]   3.85M  --.-KB/s    in 0.04s
#
# 2021-03-24 19:10:41 (97.1 MB/s) - ‘codigos.zip’ saved [4039371]
#
# Archive:  codigos.zip
#    creating: Main_Fifa/
#   inflating: Main_Fifa/main_fifa.ipynb
#   inflating: Main_Fifa/funciones_fifa.py
#    creating: Main_Fifa/.ipynb_checkpoints/
#   inflating: Main_Fifa/.ipynb_checkpoints/main_fifa-checkpoint.ipynb
#   inflating: Main_Fifa/.ipynb_checkpoints/KinectDatos-checkpoint.ipynb
#   inflating: Main_Fifa/.ipynb_checkpoints/desktop.ini
#    creating: Main_Fifa/im2/
#   inflating: Main_Fifa/im2/tsne_2D.png
#   inflating: Main_Fifa/im2/relevancia_PCA.png
#   inflating: Main_Fifa/im2/red_PCA2D.png
#   inflating: Main_Fifa/im2/mae_testing_set.png
#   inflating: Main_Fifa/im2/desktop.ini
#    creating: Main_Fifa/__pycache__/
#   inflating: Main_Fifa/__pycache__/funciones_fifa.cpython-37.pyc
#   inflating: Main_Fifa/__pycache__/funciones_housing.cpython-37.pyc
#   inflating: Main_Fifa/__pycache__/desktop.ini
#   inflating: Main_Fifa/debug.log
#    creating: Main_Fifa/datos/
#   inflating: Main_Fifa/datos/data.csv
#   inflating: Main_Fifa/datos/desktop.ini
#    creating: Main_Fifa/resultados/
#   inflating: Main_Fifa/resultados/tsne_2D.png
#   inflating: Main_Fifa/resultados/tsne_PCA2D.png
#   inflating: Main_Fifa/resultados/mae_testing_set.png
#   inflating: Main_Fifa/resultados/relevancia_PCA.png
#   inflating: Main_Fifa/resultados/red_PCA2D.png
#   inflating: Main_Fifa/resultados/desktop.ini
#   inflating: Main_Fifa/desktop.ini
# codigos.zip  Main_Fifa	sample_data

# %%
#Paso 1: Lectura
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

#from funciones_fifa import dummy_fifa, pre_exploratorio, save_fig, code_euro

from sklearn.impute import SimpleImputer 
from sklearn.model_selection import train_test_split, GridSearchCV,cross_val_score, cross_val_predict
from sklearn.metrics import mean_absolute_error
from sklearn.pipeline import Pipeline


import pandas as pd
# %matplotlib inline
csv_path = 'Main_Fifa/datos/data.csv'

Xdata = pd.read_csv(csv_path)

col_drop = ['Unnamed: 0', 'Name','ID','Photo','Flag',
           'Club Logo','Loaned From']
Xdata.drop(columns = col_drop, inplace = True)
Xdata.head()
# Out:
#    Age Nationality  Overall  ...  GKPositioning GKReflexes Release Clause
# 0   31   Argentina       94  ...           14.0        8.0        €226.5M
# 1   33    Portugal       94  ...           14.0       11.0        €127.1M
# 2   26      Brazil       92  ...           15.0       11.0        €228.1M
# 3   27       Spain       91  ...           88.0       94.0        €138.6M
# 4   27     Belgium       91  ...           10.0       13.0        €196.4M
#
# [5 rows x 82 columns]

# %%
Xdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 82 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       18207 non-null  int64
#  1   Nationality               18207 non-null  object
#  2   Overall                   18207 non-null  int64
#  3   Potential                 18207 non-null  int64
#  4   Club                      17966 non-null  object
#  5   Value                     18207 non-null  object
#  6   Wage                      18207 non-null  object
#  7   Special                   18207 non-null  int64
#  8   Preferred Foot            18159 non-null  object
#  9   International Reputation  18159 non-null  float64
#  10  Weak Foot                 18159 non-null  float64
#  11  Skill Moves               18159 non-null  float64
#  12  Work Rate                 18159 non-null  object
#  13  Body Type                 18159 non-null  object
#  14  Real Face                 18159 non-null  object
#  15  Position                  18147 non-null  object
#  16  Jersey Number             18147 non-null  float64
#  17  Joined                    16654 non-null  object
#  18  Contract Valid Until      17918 non-null  object
#  19  Height                    18159 non-null  object
#  20  Weight                    18159 non-null  object
#  21  LS                        16122 non-null  object
#  22  ST                        16122 non-null  object
#  23  RS                        16122 non-null  object
#  24  LW                        16122 non-null  object
#  25  LF                        16122 non-null  object
#  26  CF                        16122 non-null  object
#  27  RF                        16122 non-null  object
#  28  RW                        16122 non-null  object
#  29  LAM                       16122 non-null  object
#  30  CAM                       16122 non-null  object
#  31  RAM                       16122 non-null  object
#  32  LM                        16122 non-null  object
#  33  LCM                       16122 non-null  object
#  34  CM                        16122 non-null  object
#  35  RCM                       16122 non-null  object
#  36  RM                        16122 non-null  object
#  37  LWB                       16122 non-null  object
#  38  LDM                       16122 non-null  object
#  39  CDM                       16122 non-null  object
#  40  RDM                       16122 non-null  object
#  41  RWB                       16122 non-null  object
#  42  LB                        16122 non-null  object
#  43  LCB                       16122 non-null  object
#  44  CB                        16122 non-null  object
#  45  RCB                       16122 non-null  object
#  46  RB                        16122 non-null  object
#  47  Crossing                  18159 non-null  float64
#  48  Finishing                 18159 non-null  float64
#  49  HeadingAccuracy           18159 non-null  float64
#  50  ShortPassing              18159 non-null  float64
#  51  Volleys                   18159 non-null  float64
#  52  Dribbling                 18159 non-null  float64
#  53  Curve                     18159 non-null  float64
#  54  FKAccuracy                18159 non-null  float64
#  55  LongPassing               18159 non-null  float64
#  56  BallControl               18159 non-null  float64
#  57  Acceleration              18159 non-null  float64
#  58  SprintSpeed               18159 non-null  float64
#  59  Agility                   18159 non-null  float64
#  60  Reactions                 18159 non-null  float64
#  61  Balance                   18159 non-null  float64
#  62  ShotPower                 18159 non-null  float64
#  63  Jumping                   18159 non-null  float64
#  64  Stamina                   18159 non-null  float64
#  65  Strength                  18159 non-null  float64
#  66  LongShots                 18159 non-null  float64
#  67  Aggression                18159 non-null  float64
#  68  Interceptions             18159 non-null  float64
#  69  Positioning               18159 non-null  float64
#  70  Vision                    18159 non-null  float64
#  71  Penalties                 18159 non-null  float64
#  72  Composure                 18159 non-null  float64
#  73  Marking                   18159 non-null  float64
#  74  StandingTackle            18159 non-null  float64
#  75  SlidingTackle             18159 non-null  float64
#  76  GKDiving                  18159 non-null  float64
#  77  GKHandling                18159 non-null  float64
#  78  GKKicking                 18159 non-null  float64
#  79  GKPositioning             18159 non-null  float64
#  80  GKReflexes                18159 non-null  float64
#  81  Release Clause            16643 non-null  object
# dtypes: float64(38), int64(4), object(40)
# memory usage: 11.4+ MB

# %%
#Paso 2: Particion entrenamiento y validacion
# Tamaño Xtrain 70%, Tamaño Xtest 30%
import warnings
warnings.filterwarnings("ignore")

from sklearn.model_selection import train_test_split
Xtrain, Xtest = train_test_split(Xdata,test_size=0.3)
col_sal = "Release Clause"
ytrain = Xtrain[col_sal]
ytest = Xtest[col_sal]
Xtrain.drop(columns=col_sal,inplace=True)
Xtest.drop(columns=col_sal,inplace=True)

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(strategy="most_frequent")
ytrain = imputer.fit_transform(pd.DataFrame(ytrain))
ytrain = ytrain.reshape(-1)

ytest = imputer.transform(pd.DataFrame(ytest))
ytest = ytest.reshape(-1)

print(ytrain.shape, ytest.shape)
# Out:
# (12744,) (5463,)

# %%
a = ytrain[0]
print(a,print(a[1:-1]))
# Out:
# 548
# €548K None

# %%
#%%   
#codificar estadísticas -> jugadores fifa ej 88+3
def code_stats(y):
    yc = np.zeros(y.shape[0])
    for i in range(y.shape[0]):
        #print(y.iloc[i])
        
        if y.iloc[i].find("+") > -1: # encontrar signo mas en str y casteo a flotante
            yc[i] = float(y.iloc[i][:y.iloc[i].find("+")])+float(y.iloc[i][y.iloc[i].find("+")+1:])
        else: yc[i] = float(y.iloc[i])
        #print(yc[i])
    return yc   

#codificar moneda ->
def code_euro(y):
    yc = np.zeros(y.shape[0])
    for i in range(y.shape[0]):
      #  print(i,y[i])
        if y[i][-1]=='M': yc[i] = float(y[i][1:-1])*10**6 #buscar M y reemplazar 10^6
        elif y[i][-1]=='K': yc[i] = float(y[i][1:-1])*10**3 # buscar K y reemplazar por 10^3
        else: yc[i] = float(y[i][1:])
        #print(yc[i])
    return yc

# %%
#codificar salida
ytrain_num = code_euro(ytrain)
ytest_num = code_euro(ytest)

# %%
ytrain_num[:5]
# Out:
# array([  548000.,  2900000.,  1100000.,   232000., 12000000.])

# %%
import matplotlib.pyplot as plt
plt.hist(ytrain_num,bins = 100)
plt.show()

plt.boxplot(ytrain_num)
plt.show()

# %%
#definir columnas tipo string  para codificar moneda, estadistica fifa y categoricas
col_euro = ['Value','Wage'];
col_stats = ['LS','ST','RS','LW','LF','CF','RF','RW','LAM',
             'CAM','RAM','LM','LCM','CM','RCM','RM','LWB',
             'LDM','CDM','RDM','RWB','LB','LCB','CB','RCB','RB'];

cat = ['Nationality','Club','Body Type','Position','Preferred Foot',
        'Work Rate','Real Face','Contract Valid Until']
items = [] 
for i in cat:
    items += [list(Xdata[i].value_counts().index)]
cat_usr = dict(zip(cat, items))

# %%
Xdata['Nationality'].value_counts().index
# Out:
# Index(['England', 'Germany', 'Spain', 'Argentina', 'France', 'Brazil', 'Italy',
#        'Colombia', 'Japan', 'Netherlands',
#        ...
#        'Rwanda', 'Fiji', 'Guam', 'St Lucia', 'New Caledonia', 'Kuwait',
#        'United Arab Emirates', 'Qatar', 'Mauritius', 'São Tomé & Príncipe'],
#       dtype='object', length=164)

# %% [markdown]
# # Crear clase propia de preproceso para Fifa

# %%
#%% dummy transformer
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.impute import SimpleImputer 
from sklearn.preprocessing import OrdinalEncoder,OneHotEncoder

class dummy_fifa(BaseEstimator,TransformerMixin):
    #inicializacion de clase y varaibles
    def __init__(self, col_euro,col_stats, cat_usr): #constructor clase
        self.col_euro = col_euro #lista atributos tipo moneda
        self.col_stats = col_stats #lista atributos tipo estadistica
        self.cat_usr = cat_usr #lista de atributos categoricos

    def fit(self,X, *_):
        Xi = X.copy() #copiar dataset para no reemplazar original
        self.imputer_num = SimpleImputer(strategy="most_frequent") #crear imputador tipo modo
        self.a = Xi.columns[np.sum(Xi.isna())> 0] #encontrar columnas con datos faltantes
        #print(a)
        self.imputer_num.fit(Xi[self.a]) # ajustar imputador
        
        Xi[self.a] = self.imputer_num.transform(Xi[self.a]) #evaluar  sobre datos imputador
        #print('Cod Euros\n')
        for i in self.col_euro: #codificar tipo moneda
         #   print(i)
            Xi[i] = code_euro(np.array(Xi[i]))
        #print('Cod stats\n')    
        for i in self.col_stats: #codificar datos estadisticos
         #   print(i)
            Xi[i] = code_stats(Xi[i])
        
        #height, wieght corregir formato
        Xi['Height'].replace(regex=["'"], value='.',inplace=True)        
        for i in Xi.index:
            #print(float(Xi.loc[i,'Weight'][:-3]))
            Xi.loc[i,'Weight'] = float(Xi.loc[i,'Weight'][:-3])
            Xi.loc[i,'Height'] = float(Xi.loc[i,'Height'])
        
        Xi['Height'] = Xi['Height'].astype('float64');#print(Xi['Height'].dtype)
        
        Xi['Joined'] = Xi['Joined'].replace(regex="/",value="")
        Xi['Joined'] = Xi['Joined'].astype('float64')
        
        
        
        cat = [] #codificar variables categoricas con ordinal encoder
        for i in self.cat_usr.keys():
            cat = cat + [[*self.cat_usr.get(i)]]
        self.col_cat_usr = OrdinalEncoder(categories=cat) # OneHotEncoder(categories=cat,sparse=False)
        Xi[[*self.cat_usr.keys()]] =self.col_cat_usr.fit_transform(Xi[[*self.cat_usr.keys()]])
        
        #self.col_cat = Xi.columns[Xi.dtypes=='O']
        #self.cod = OrdinalEncoder()
        #self.cod.fit(Xi[self.col_cat])
        
        return self    

    def transform(self, X, *_):#funcion transformador-> pensando datos nuevos
        Xi = X.copy()
        Xi[self.a] = self.imputer_num.transform(Xi[self.a])
        
        for i in self.col_euro:
         #   print(i)
            Xi[i] = code_euro(np.array(Xi[i]))
        #print('Cod stats\n')    
        for i in self.col_stats:
         #   print(i)
            Xi[i] = code_stats(Xi[i])
        
        #height, wieght
        Xi['Height'].replace(regex=["'"], value='.',inplace=True)        
        for i in Xi.index:
            #print(float(Xi.loc[i,'Weight'][:-3]))
            Xi.loc[i,'Weight'] = float(Xi.loc[i,'Weight'][:-3])
            Xi.loc[i,'Height'] = float(Xi.loc[i,'Height'])
        
        Xi['Height'] = Xi['Height'].astype('float64')
        Xi['Weight'] = Xi['Weight'].astype('float64')
            
        Xi['Joined'] = Xi['Joined'].replace(regex="/",value="")
        Xi['Joined'] = Xi['Joined'].astype('float64')
        
        Xi[[*self.cat_usr.keys()]] =self.col_cat_usr.transform(Xi[[*self.cat_usr.keys()]])
        #Xi[self.col_cat]= self.cod.transform(Xi[self.col_cat])
        return Xi
    
    def fit_transform(self,X,*_):
        self.fit(X)
        return self.transform(X)

# %%
dummy = dummy_fifa(col_euro=col_euro,col_stats=col_stats,cat_usr = cat_usr)
Xtrain_pre = dummy.fit_transform(Xtrain)

# %%
Xtest_pre = dummy.transform(Xtest) #no se puede fit solo transform

# %%
Xtest_pre.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5463 entries, 7619 to 7144
# Data columns (total 81 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       5463 non-null   int64
#  1   Nationality               5463 non-null   float64
#  2   Overall                   5463 non-null   int64
#  3   Potential                 5463 non-null   int64
#  4   Club                      5463 non-null   float64
#  5   Value                     5463 non-null   float64
#  6   Wage                      5463 non-null   float64
#  7   Special                   5463 non-null   int64
#  8   Preferred Foot            5463 non-null   float64
#  9   International Reputation  5463 non-null   float64
#  10  Weak Foot                 5463 non-null   float64
#  11  Skill Moves               5463 non-null   float64
#  12  Work Rate                 5463 non-null   float64
#  13  Body Type                 5463 non-null   float64
#  14  Real Face                 5463 non-null   float64
#  15  Position                  5463 non-null   float64
#  16  Jersey Number             5463 non-null   float64
#  17  Joined                    5463 non-null   float64
#  18  Contract Valid Until      5463 non-null   float64
#  19  Height                    5463 non-null   float64
#  20  Weight                    5463 non-null   float64
#  21  LS                        5463 non-null   float64
#  22  ST                        5463 non-null   float64
#  23  RS                        5463 non-null   float64
#  24  LW                        5463 non-null   float64
#  25  LF                        5463 non-null   float64
#  26  CF                        5463 non-null   float64
#  27  RF                        5463 non-null   float64
#  28  RW                        5463 non-null   float64
#  29  LAM                       5463 non-null   float64
#  30  CAM                       5463 non-null   float64
#  31  RAM                       5463 non-null   float64
#  32  LM                        5463 non-null   float64
#  33  LCM                       5463 non-null   float64
#  34  CM                        5463 non-null   float64
#  35  RCM                       5463 non-null   float64
#  36  RM                        5463 non-null   float64
#  37  LWB                       5463 non-null   float64
#  38  LDM                       5463 non-null   float64
#  39  CDM                       5463 non-null   float64
#  40  RDM                       5463 non-null   float64
#  41  RWB                       5463 non-null   float64
#  42  LB                        5463 non-null   float64
#  43  LCB                       5463 non-null   float64
#  44  CB                        5463 non-null   float64
#  45  RCB                       5463 non-null   float64
#  46  RB                        5463 non-null   float64
#  47  Crossing                  5463 non-null   float64
#  48  Finishing                 5463 non-null   float64
#  49  HeadingAccuracy           5463 non-null   float64
#  50  ShortPassing              5463 non-null   float64
#  51  Volleys                   5463 non-null   float64
#  52  Dribbling                 5463 non-null   float64
#  53  Curve                     5463 non-null   float64
#  54  FKAccuracy                5463 non-null   float64
#  55  LongPassing               5463 non-null   float64
#  56  BallControl               5463 non-null   float64
#  57  Acceleration              5463 non-null   float64
#  58  SprintSpeed               5463 non-null   float64
#  59  Agility                   5463 non-null   float64
#  60  Reactions                 5463 non-null   float64
#  61  Balance                   5463 non-null   float64
#  62  ShotPower                 5463 non-null   float64
#  63  Jumping                   5463 non-null   float64
#  64  Stamina                   5463 non-null   float64
#  65  Strength                  5463 non-null   float64
#  66  LongShots                 5463 non-null   float64
#  67  Aggression                5463 non-null   float64
#  68  Interceptions             5463 non-null   float64
#  69  Positioning               5463 non-null   float64
#  70  Vision                    5463 non-null   float64
#  71  Penalties                 5463 non-null   float64
#  72  Composure                 5463 non-null   float64
#  73  Marking                   5463 non-null   float64
#  74  StandingTackle            5463 non-null   float64
#  75  SlidingTackle             5463 non-null   float64
#  76  GKDiving                  5463 non-null   float64
#  77  GKHandling                5463 non-null   float64
#  78  GKKicking                 5463 non-null   float64
#  79  GKPositioning             5463 non-null   float64
#  80  GKReflexes                5463 non-null   float64
# dtypes: float64(77), int64(4)
# memory usage: 3.6 MB

# %%
corr_matrix = Xtrain_pre.corr()
corr_matrix.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_78f9d9ca_8cd8_11eb_bb6e_0242ac1c0002row0_col0,#T_78f9d9ca_8cd8_11eb_bb6e_0242ac1c0002row1_col1,#T_78f9d9ca_8cd8_11eb_bb6e_0242ac1c0002row2_col2,#T_78f9d9ca_8cd8_11eb_bb6e_0242ac1c0002row3_col3,#T_78f9d9ca_8cd8_11eb_bb6e_0242ac1c0002row4_col4,#T_78f9d9ca_8cd8_11eb_bb6e_0242ac1c0002row5_col5,#T_78f9d9ca_8cd8_11eb_bb6e_0242ac1c0002row6_col6,#T_78f9d9ca_8cd8_11eb_bb6e_0242ac1c0002row7_col7,#T_78f9d9ca_8cd8_11eb_bb6e_0242ac1c0002row8_col8,#T_78f9d9ca_8cd8_11eb_bb6e_0242ac1c0002row9_col9,#T_78f9d9ca_8cd8_11eb_bb6e_0242ac1c0002row10_col10,#T_78f9d9ca_8cd8_11eb_bb6e_0242ac1c0002row11_col11,#T_78f9d9ca_8cd8_11eb_bb6e_0242ac1c0002row12_col12,#T_78f9d9ca_8cd8_11eb_bb6e_0242ac1c0002row13_col13,#T_78f9d9ca_8cd8_11eb_bb6e_0242ac1c0002row14_col14,#T_78f9d9ca_8cd8_11eb_bb6e_0242ac1c0002row15_col15,#T_78f9d9ca_8cd8_11eb_bb6e_0242ac1c0002row16_col16,#T_78f9d9ca_8cd8_11eb_bb6e_0242ac1c0002row17_col17,#T_78f9d9ca_8cd8_11eb_bb6e_0242ac1c0002row18_col18,#T_78f9d9ca_8cd8_11eb_bb6e_0242ac1c0002row19_col19,#T_78f9d9ca_8cd8_11eb_bb6e_0242ac1c0002row20_col20,#T_78f9d9ca_8cd8_11eb_bb6e_0242ac1c0002row21_col21,#T_78f9d9ca_8cd8_11eb_bb6e_0242ac1c0002row21_col22,#T_78f9d9ca_8cd8_11eb_bb6e_0242ac1c0002row21_col23,#T_78f9d9ca_8cd8_11eb_bb6e_0242ac1c0002row22_col21,#T_78f9d9ca_8cd8_11eb_bb6e_0242ac1c0002row22_col22,#T_78f9d9ca_8cd8_11eb_bb6e_0242ac1c0002row22_col23,#T_78f9d9ca_8cd8_11eb_bb6e_0242ac1c0002row23_col21,#T_78f9d9ca_8cd8_11eb_bb6e_0242ac1c0002row23_col22,#T_78f9d9ca_8cd8_11eb_bb6e_0242ac1c0002row23_col23,#T_78f9d9ca_8cd8_11eb_bb6e_0242ac1c0002row24_col24,#T_78f9d9ca_8cd8_11eb_bb6e_0242ac1c0002row24_col28,#T_78f9d9ca_8cd8_11eb_bb6e_0242ac1c0002row25_col25,#T_78f9d9ca_8cd8_11eb_bb6e_0242ac1c0002row25_col26,#T_78f9d9ca_8cd8_11eb_bb6e_0242ac1c0002row25_col27,#T_78f9d9ca_8cd8_11eb_bb6e_0242ac1c0002row26_col25,#T_78f9d9ca_8cd8_11eb_bb6e_0242ac1c0002row26_col26,#T_78f9d9ca_8cd8_11eb_bb6e_0242ac1c0002row26_col27,#T_78f9d9ca_8cd8_11eb_bb6e_0242ac1c0002row27_col25,#T_78f9d9ca_8cd8_11eb_bb6e_0242ac1c0002row27_col26,#T_78f9d9ca_8cd8_11eb_bb6e_0242ac1c0002row27_col27,#T_78f9d9ca_8cd8_11eb_bb6e_0242ac1c0002row28_col24,#T_78f9d9ca_8cd8_11eb_bb6e_0242ac1c0002row28_col28,#T_78f9d9ca_8cd8_11eb_bb6e_0242ac1c0002row29_col29,#T_78f9d9ca_8cd8_11eb_bb6e_0242ac1c0002row29_col30,#T_78f9d9ca_8cd8_11eb_bb6e_0242ac1c0002row29_col31,#T_78f9d9ca_8cd8_11eb_bb6e_0242ac1c0002row30_col29,#T_78f9d9ca_8cd8_11eb_bb6e_0242ac1c0002row30_col30,#T_78f9d9ca_8cd8_11eb_bb6e_0242ac1c0002row30_col31,#T_78f9d9ca_8cd8_11eb_bb6e_0242ac1c0002row31_col29,#T_78f9d9ca_8cd8_11eb_bb6e_0242ac1c0002row31_col30,#T_78f9d9ca_8cd8_11eb_bb6e_0242ac1c0002row31_col31,#T_78f9d9ca_8cd8_11eb_bb6e_0242ac1c0002row32_col32,#T_78f9d9ca_8cd8_11eb_bb6e_0242ac1c0002row32_col36,#T_78f9d9ca_8cd8_11eb_bb6e_0242ac1c0002row33_col33,#T_78f9d9ca_8cd8_11eb_bb6e_0242ac1c0002row33_col34,#T_78f9d9ca_8cd8_11eb_bb6e_0242ac1c0002row33_col35,#T_78f9d9ca_8cd8_11eb_bb6e_0242ac1c0002row34_col33,#T_78f9d9ca_8cd8_11eb_bb6e_0242ac1c0002row34_col34,#T_78f9d9ca_8cd8_11eb_bb6e_0242ac1c0002row34_col35,#T_78f9d9ca_8cd8_11eb_bb6e_0242ac1c0002row35_col33,#T_78f9d9ca_8cd8_11eb_bb6e_0242ac1c0002row35_col34,#T_78f9d9ca_8cd8_11eb_bb6e_0242ac1c0002row35_col35,#T_78f9d9ca_8cd8_11eb_bb6e_0242ac1c0002row36_col32,#T_78f9d9ca_8cd8_11eb_bb6e_0242ac1c0002row36_col36,#T_78f9d9ca_8cd8_11eb_bb6e_0242ac1c0002row37_col37,#T_78f9d9ca_8cd8_11eb_bb6e_0242ac1c0002row37_col41,#T_78f9d9ca_8cd8_11eb_bb6e_0242ac1c0002row38_col38,#T_78f9d9ca_8cd8_11eb_bb6e_0242ac1c0002row38_col39,#T_78f9d9ca_8cd8_11eb_bb6e_0242ac1c0002row38_col40,#T_78f9d9ca_8cd8_11eb_bb6e_0242ac1c0002row39_col38,#T_78f9d9ca_8cd8_11eb_bb6e_0242ac1c0002row39_col39,#T_78f9d9ca_8cd8_11eb_bb6e_0242ac1c0002row39_col40,#T_78f9d9ca_8cd8_11eb_bb6e_0242ac1c0002row40_col38,#T_78f9d9ca_8cd8_11eb_bb6e_0242ac1c0002row40_col39,#T_78f9d9ca_8cd8_11eb_bb6e_0242ac1c0002row40_col40,#T_78f9d9ca_8cd8_11eb_bb6e_0242ac1c0002row41_col37,#T_78f9d9ca_8cd8_11eb_bb6e_0242ac1c0002row41_col41,#T_78f9d9ca_8cd8_11eb_bb6e_0242ac1c0002row ...
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_78f9d9ca_8cd8_11eb_bb6e_0242ac1c0002row0_col1,#T_78f9d9ca_8cd8_11eb_bb6e_0242ac1c0002row4_col37,#T_78f9d9ca_8cd8_11eb_bb6e_0242ac1c0002row4_col41,#T_78f9d9ca_8cd8_11eb_bb6e_0242ac1c0002row5_col4,#T_78f9d9ca_8cd8_11eb_bb6e_0242ac1c0002row19_col8,#T_78f9d9ca_8cd8_11eb_bb6e_0242ac1c0002row47_col1,#T_78f9d9ca_8cd8_11eb_bb6e_0242ac1c0002row50_col1,#T_78f9d9ca_8cd8_11eb_bb6e_0242ac1c0002row59_col19,#T_78f9d9ca_8cd8_11eb_bb6e_0242ac1c0002row61_col17,#T_78f9d9ca_8cd8_11eb_bb6e_0242ac1c0002row63_col1,#T_78f9d9ca_8cd8_11eb_bb6e_0242ac1c0002row63_col13,#T_78f9d9ca_8cd8_11eb_bb6e_0242ac1c0002row65_col8,#T_78f9d9ca_8cd8_11eb_bb6e_0242ac1c0002row65_col29,#T_78f9d9ca_8cd8_11eb_bb6e_0242ac1c0002row65_col30,#T_78f9d9ca_8cd8_11eb_bb6e_0242ac1c0002row65_col31,#T_78f9d9ca_8cd8_11eb_bb6e_0242ac1c0002row65_col32,#T_78f9d9ca_8cd8_11eb_bb6e_0242ac1c0002row65_col36,#T_78f9d9ca_8cd8_11eb_bb6e_0242ac1c0002row72_col16,#T_78f9d9ca_8cd8_11eb_bb6e_0242ac1c0002row75_col32,#T_78f9d9ca_8cd8_11eb_bb6e_0242ac1c0002row75_col36,#T_78f9d9ca_8cd8_11eb_bb6e_0242ac1c0002row76_col18,#T_78f9d9ca_8cd8_11eb_bb6e_0242ac1c0002row77_col17,#T_78f9d9ca_8cd8_11eb_bb6e_0242ac1c0002row78_col18,#T_78f9d9ca_8cd8_11eb_bb6e_0242ac1c0002row79_col17{
#             background-color:  #4b64d5;
#             color:  #f1f1f1;
#         }#T_78f9d9ca_8cd8_11eb_bb6e_0242ac1c0002row0_col2,#T_78f9d9ca_8cd8_11eb_bb6e_0242ac1c0002row3_col49,#T_78f9d9ca_8cd8_11eb_bb6e_0242ac1c0002row3_col66,#T_78f9d9ca_8cd8_11eb_bb6e_0242ac1c0002row5_col24,#T_78f9d9ca_8cd8_11eb_bb6e_0242ac1c0002row5_col28

# %%
import seaborn as sns
sns.heatmap(corr_matrix,xticklabels=corr_matrix.columns.values,yticklabels=corr_matrix.columns.values)
plt.tight_layout()
#plt.savefig('results/corr_matrix.pdf', format='pdf', dpi=300)
plt.show()

# %%
Xtrain_pre2 = Xtrain_pre.copy()
Xtrain_pre2['Salida'] = ytrain_num
corr_matrix = abs(Xtrain_pre2.corr())
corr_matrix['Salida'].sort_values(ascending=False)
# Out:
# Salida                      1.000000
# Value                       0.968365
# Wage                        0.828171
# International Reputation    0.628569
# Overall                     0.592658
#                               ...
# GKHandling                  0.018207
# GKReflexes                  0.017914
# Height                      0.016833
# GKPositioning               0.016464
# Nationality                 0.015843
# Name: Salida, Length: 82, dtype: float64

# %%
import matplotlib.pyplot as plt
plt.scatter(Xtrain_pre['Overall'],ytrain_num)

# %% [markdown]
# # Modelo de regresión

# %%
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LinearRegression,SGDRegressor
from sklearn.preprocessing import StandardScaler
steps = [('preproceso',dummy_fifa(col_euro=col_euro,col_stats=col_stats,cat_usr = cat_usr)), 
         ('scaler', StandardScaler()),
         ('regresion',LinearRegression())
         ]
metodo_full = Pipeline(steps=steps)
metodo_full

metodo_full.fit(Xtrain,ytrain_num) #entrena todos los pasos
# Out:
# Pipeline(memory=None,
#          steps=[('preproceso',
#                  dummy_fifa(cat_usr={'Body Type': ['Normal', 'Lean', 'Stocky',
#                                                    'PLAYER_BODY_TYPE_25',
#                                                    'Shaqiri', 'Neymar',
#                                                    'C. Ronaldo', 'Messi',
#                                                    'Courtois', 'Akinfenwa'],
#                                      'Club': ['Chelsea', 'Frosinone',
#                                               'Liverpool',
#                                               'Wolverhampton Wanderers',
#                                               'Burnley', 'Borussia Dortmund',
#                                               'FC Barcelona', 'Empoli',
#                                               'Atlético Madrid', 'AS Monaco',
#                                               'Eintracht Frankfurt...
#                             col_euro=['Value', 'Wage'],
#                             col_stats=['LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF',
#                                        'RW', 'LAM', 'CAM', 'RAM', 'LM', 'LCM',
#                                        'CM', 'RCM', 'RM', 'LWB', 'LDM', 'CDM',
#                                        'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB',
#                                        'RB'])),
#                 ('scaler',
#                  StandardScaler(copy=True, with_mean=True, with_std=True)),
#                 ('regresion',
#                  LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#                                   normalize=False))],
#          verbose=False)

# %%
ytest_e = metodo_full.predict(Xtest)

# %%
Xtest.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5463 entries, 7619 to 7144
# Data columns (total 81 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       5463 non-null   int64
#  1   Nationality               5463 non-null   object
#  2   Overall                   5463 non-null   int64
#  3   Potential                 5463 non-null   int64
#  4   Club                      5400 non-null   object
#  5   Value                     5463 non-null   object
#  6   Wage                      5463 non-null   object
#  7   Special                   5463 non-null   int64
#  8   Preferred Foot            5448 non-null   object
#  9   International Reputation  5448 non-null   float64
#  10  Weak Foot                 5448 non-null   float64
#  11  Skill Moves               5448 non-null   float64
#  12  Work Rate                 5448 non-null   object
#  13  Body Type                 5448 non-null   object
#  14  Real Face                 5448 non-null   object
#  15  Position                  5445 non-null   object
#  16  Jersey Number             5445 non-null   float64
#  17  Joined                    4994 non-null   object
#  18  Contract Valid Until      5385 non-null   object
#  19  Height                    5448 non-null   object
#  20  Weight                    5448 non-null   object
#  21  LS                        4841 non-null   object
#  22  ST                        4841 non-null   object
#  23  RS                        4841 non-null   object
#  24  LW                        4841 non-null   object
#  25  LF                        4841 non-null   object
#  26  CF                        4841 non-null   object
#  27  RF                        4841 non-null   object
#  28  RW                        4841 non-null   object
#  29  LAM                       4841 non-null   object
#  30  CAM                       4841 non-null   object
#  31  RAM                       4841 non-null   object
#  32  LM                        4841 non-null   object
#  33  LCM                       4841 non-null   object
#  34  CM                        4841 non-null   object
#  35  RCM                       4841 non-null   object
#  36  RM                        4841 non-null   object
#  37  LWB                       4841 non-null   object
#  38  LDM                       4841 non-null   object
#  39  CDM                       4841 non-null   object
#  40  RDM                       4841 non-null   object
#  41  RWB                       4841 non-null   object
#  42  LB                        4841 non-null   object
#  43  LCB                       4841 non-null   object
#  44  CB                        4841 non-null   object
#  45  RCB                       4841 non-null   object
#  46  RB                        4841 non-null   object
#  47  Crossing                  5448 non-null   float64
#  48  Finishing                 5448 non-null   float64
#  49  HeadingAccuracy           5448 non-null   float64
#  50  ShortPassing              5448 non-null   float64
#  51  Volleys                   5448 non-null   float64
#  52  Dribbling                 5448 non-null   float64
#  53  Curve                     5448 non-null   float64
#  54  FKAccuracy                5448 non-null   float64
#  55  LongPassing               5448 non-null   float64
#  56  BallControl               5448 non-null   float64
#  57  Acceleration              5448 non-null   float64
#  58  SprintSpeed               5448 non-null   float64
#  59  Agility                   5448 non-null   float64
#  60  Reactions                 5448 non-null   float64
#  61  Balance                   5448 non-null   float64
#  62  ShotPower                 5448 non-null   float64
#  63  Jumping                   5448 non-null   float64
#  64  Stamina                   5448 non-null   float64
#  65  Strength                  5448 non-null   float64
#  66  LongShots                 5448 non-null   float64
#  67  Aggression                5448 non-null   float64
#  68  Interceptions             5448 non-null   float64
#  69  Positioning               5448 non-null   float64
#  70  Vision                    5448 non-null   float64
#  71  Penalties                 5448 non-null   float64
#  72  Composure                 5448 non-null   float64
#  73  Marking                   5448 non-null   float64
#  74  StandingTackle            5448 non-null   float64
#  75  SlidingTackle             5448 non-null   float64
#  76  GKDiving                  5448 non-null   float64
#  77  GKHandling                5448 non-null   float64
#  78  GKKicking                 5448 non-null   float64
#  79  GKPositioning             5448 non-null   float64
#  80  GKReflexes                5448 non-null   float64
# dtypes: float64(38), int64(4), object(39)
# memory usage: 3.4+ MB

# %%
plt.plot(ytest_num,label='original')
plt.plot(ytest_e,'r',label='estimado')
plt.legend()
plt.show()

# %%
plt.scatter(ytest_num,ytest_e)
plt.show()

# %%
metodo_full.steps[2][1].coef_.shape
plt.stem(abs(metodo_full.steps[2][1].coef_))
plt.show()

# %%
ind=abs(metodo_full.steps[2][1].coef_).argsort()

# %%
Xtrain.columns[ind[::-1]]
# Out:
# Index(['LDM', 'CDM', 'CB', 'RCB', 'LCB', 'LWB', 'RWB', 'RB', 'LB', 'RDM',
#        'LAM', 'RW', 'LW', 'LM', 'RM', 'RAM', 'CAM', 'ST', 'RS', 'LS', 'CM',
#        'CF', 'LF', 'RCM', 'LCM', 'RF', 'Value', 'Wage', 'Overall', 'Special',
#        'Contract Valid Until', 'GKPositioning', 'Age',
#        'International Reputation', 'StandingTackle', 'Crossing', 'Volleys',
#        'Potential', 'SlidingTackle', 'Club', 'Positioning', 'Finishing',
#        'LongPassing', 'ShotPower', 'Skill Moves', 'Joined', 'GKHandling',
#        'SprintSpeed', 'Position', 'Weight', 'Penalties', 'BallControl',
#        'HeadingAccuracy', 'GKDiving', 'LongShots', 'Composure', 'Nationality',
#        'Real Face', 'Curve', 'ShortPassing', 'Body Type', 'GKKicking',
#        'Aggression', 'Agility', 'Weak Foot', 'Strength', 'Interceptions',
#        'Marking', 'Work Rate', 'Jersey Number', 'Balance', 'Stamina',
#        'Reactions', 'Vision', 'GKReflexes', 'Jumping', 'Acceleration',
#        'Dribbling', 'FKAccuracy', 'Preferred Foot', 'Height'],
#       dtype='object')
